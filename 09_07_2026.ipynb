# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/global_climate_energy_2020_2024.csv")

print(df.head())
print(df.info())
# Out:
#          date  country  avg_temperature  humidity  co2_emission  \
# 0  2020-01-01  Germany            28.29     31.08        212.63
# 1  2020-01-02  Germany            28.38     37.94        606.05
# 2  2020-01-03  Germany            28.74     57.67        268.72
# 3  2020-01-04  Germany            26.66     51.34        167.32
# 4  2020-01-05  Germany            26.81     65.38        393.89
#
#    energy_consumption  renewable_share  urban_population  \
# 0            11348.75            14.42             76.39
# 1             4166.64             5.63             86.26
# 2             4503.80            14.20             75.92
# 3             3259.13            13.84             63.15
# 4             7023.72             6.93             76.02
#
#    industrial_activity_index  energy_price
# 0                      51.22         83.93
# 1                      78.27        110.40
# 2                      48.96        173.58
# 3                      97.42         89.13
# ...

# %%
print(df.shape)
print(df.columns)
print(df.dtypes)
print(df.describe())
print(df.isnull().sum())
# Out:
# (30108, 10)
# Index(['date', 'country', 'avg_temperature', 'humidity', 'co2_emission',
#        'energy_consumption', 'renewable_share', 'urban_population',
#        'industrial_activity_index', 'energy_price'],
#       dtype='object')
# date                          object
# country                       object
# avg_temperature              float64
# humidity                     float64
# co2_emission                 float64
# energy_consumption           float64
# renewable_share              float64
# urban_population             float64
# industrial_activity_index    float64
# energy_price                 float64
# dtype: object
#        avg_temperature      humidity  co2_emission  energy_consumption  \
# count     30108.000000  30108.000000  30108.000000        30108.000000
# mean         13.784545     60.041185    445.550254         7284.715059
# std          10.088871     17.305868    234.667700         3697.301355
# ...

# %%
num_cols = df.select_dtypes(include=np.number).columns
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

print(df.isnull().sum())
# Out:
# date                         0
# country                      0
# avg_temperature              0
# humidity                     0
# co2_emission                 0
# energy_consumption           0
# renewable_share              0
# urban_population             0
# industrial_activity_index    0
# energy_price                 0
# dtype: int64

# %%
print(df.describe())
print(df.corr(numeric_only=True))
# Out:
#        avg_temperature      humidity  co2_emission  energy_consumption  \
# count     30108.000000  30108.000000  30108.000000        30108.000000
# mean         13.784545     60.041185    445.550254         7284.715059
# std          10.088871     17.305868    234.667700         3697.301355
# min          -9.600000     30.000000     50.150000         1001.930000
# 25%           5.820000     45.050000    248.040000         4169.597500
# 50%          14.060000     60.090000    421.570000         6912.805000
# 75%          21.000000     75.090000    629.572500        10161.110000
# max          38.710000     89.990000    999.850000        15998.050000
#
#        renewable_share  urban_population  industrial_activity_index  \
# count     30108.000000      30108.000000               30108.000000
# mean         15.828666         75.015148                  70.073045
# std           5.332486          8.661729                  17.328036
# ...

# %%
# ===========================================================
# SUMMARY
#
# 1. Imported the sustainability dataset.
#
# 2. Explored the dataset using:
#    - head()
#    - info()
#    - describe()
#    - shape
#    - columns
#
# 3. Checked data types.
#
# 4. Identified missing values.
#
# 5. Filled numerical missing values using Median.
#
# 6. Filled categorical missing values using Mode.
#
# 7. Studied relationships among features.
#
# 8. Calculated descriptive statistics.
#
# 9. Generated visualizations for understanding data.
#
# 10. Successfully cleaned the dataset and prepared it
#     for further machine learning or analysis.
#
# ===========================================================
